# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "2"

import tensorflow as tf
from tensorflow.keras import datasets, layers, models, regularizers, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
 
EPOCHS=50
NUM_CLASSES = 10
    

def load_data():
    (x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
 
    #normalize 
    mean = np.mean(x_train,axis=(0,1,2,3))
    std = np.std(x_train,axis=(0,1,2,3))
    x_train = (x_train-mean)/(std+1e-7)
    x_test = (x_test-mean)/(std+1e-7)
 
    y_train =  tf.keras.utils.to_categorical(y_train,NUM_CLASSES)
    y_test =  tf.keras.utils.to_categorical(y_test,NUM_CLASSES)

    return x_train, y_train, x_test, y_test

def build_model(): 
    model = models.Sequential()
    
    #1st blocl
    model.add(layers.Conv2D(32, (3,3), padding='same', 
        input_shape=x_train.shape[1:], activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(32, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.2))

    #2nd block
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.3))

    #3d block 
    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.4))

    #dense  
    model.add(layers.Flatten())
    model.add(layers.Dense(NUM_CLASSES, activation='softmax'))
    return model
 

(x_train, y_train, x_test, y_test) = load_data()
model = build_model()
model.summary()

model.compile(loss='categorical_crossentropy', 
            optimizer='RMSprop', 
            metrics=['accuracy'])

#image augmentation
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    )
datagen.fit(x_train)
 
#train
batch_size = 64
model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
          epochs=EPOCHS,
          verbose=1,validation_data=(x_test,y_test))

#save to disk
model_json = model.to_json()
with open('cifar10_datageneration_architecture.json', 'w') as json_file:
    json_file.write(model_json)
model.save_weights('cifar10_datageneration.weights.h5') 

#test
scores = model.evaluate(x_test, y_test, batch_size=128, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
# Out:
# C:\Users\shkwon\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        20,490 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 309,290 (1.18 MB)
#  Trainable params: 308,394 (1.18 MB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/50
# C:\Users\shkwon\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 61ms/step - accuracy: 0.2971 - loss: 2.5458 - val_accuracy: 0.4470 - val_loss: 1.8543
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.4869 - loss: 1.5716 - val_accuracy: 0.5650 - val_loss: 1.3490
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.5487 - loss: 1.3400 - val_accuracy: 0.6294 - val_loss: 1.0527
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.5945 - loss: 1.1998 - val_accuracy: 0.6621 - val_loss: 0.9793
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 71ms/step - accuracy: 0.6293 - loss: 1.0818 - val_accuracy: 0.6819 - val_loss: 0.9617
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.6496 - loss: 1.0077 - val_accuracy: 0.6801 - val_loss: 0.9889
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.6758 - loss: 0.9422 - val_accuracy: 0.6973 - val_loss: 0.9130
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.6856 - loss: 0.9058 - val_accuracy: 0.7017 - val_loss: 0.9346
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 71ms/step - accuracy: 0.7000 - loss: 0.8680 - val_accuracy: 0.7570 - val_loss: 0.7291
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.7114 - loss: 0.8421 - val_accuracy: 0.7703 - val_loss: 0.6865
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 85ms/step - accuracy: 0.7203 - loss: 0.8020 - val_accuracy: 0.7501 - val_loss: 0.7885
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.7239 - loss: 0.7974 - val_accuracy: 0.7735 - val_loss: 0.6987
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.7352 - loss: 0.7662 - val_accuracy: 0.7391 - val_loss: 0.8096
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.7420 - loss: 0.7467 - val_accuracy: 0.7744 - val_loss: 0.6926
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.7440 - loss: 0.7386 - val_accuracy: 0.7594 - val_loss: 0.7472
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.7531 - loss: 0.7167 - val_accuracy: 0.7810 - val_loss: 0.6609
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.7566 - loss: 0.7031 - val_accuracy: 0.7745 - val_loss: 0.7000
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 73ms/step - accuracy: 0.7582 - loss: 0.6999 - val_accuracy: 0.7985 - val_loss: 0.6141
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 83ms/step - accuracy: 0.7598 - loss: 0.6977 - val_accuracy: 0.8124 - val_loss: 0.5637
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 77ms/step - accuracy: 0.7675 - loss: 0.6732 - val_accuracy: 0.7755 - val_loss: 0.7153
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.7691 - loss: 0.6674 - val_accuracy: 0.7910 - val_loss: 0.6477
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.7748 - loss: 0.6473 - val_accuracy: 0.8154 - val_loss: 0.5630
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.7685 - loss: 0.6600 - val_accuracy: 0.8106 - val_loss: 0.5814
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.7771 - loss: 0.6441 - val_accuracy: 0.8160 - val_loss: 0.5630
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.7796 - loss: 0.6393 - val_accuracy: 0.7978 - val_loss: 0.6352
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.7796 - loss: 0.6389 - val_accuracy: 0.8110 - val_loss: 0.5837
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.7851 - loss: 0.6225 - val_accuracy: 0.8007 - val_loss: 0.6277
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.7835 - loss: 0.6292 - val_accuracy: 0.8126 - val_loss: 0.5769
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.7834 - loss: 0.6218 - val_accuracy: 0.8220 - val_loss: 0.5379
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 90ms/step - accuracy: 0.7912 - loss: 0.6048 - val_accuracy: 0.8161 - val_loss: 0.5581
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.7943 - loss: 0.6051 - val_accuracy: 0.8021 - val_loss: 0.6264
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.7918 - loss: 0.6034 - val_accuracy: 0.8221 - val_loss: 0.5547
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.7929 - loss: 0.5954 - val_accuracy: 0.8005 - val_loss: 0.6586
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.7953 - loss: 0.5875 - val_accuracy: 0.8300 - val_loss: 0.5254
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 95ms/step - accuracy: 0.7948 - loss: 0.5918 - val_accuracy: 0.8142 - val_loss: 0.5701
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 92ms/step - accuracy: 0.7965 - loss: 0.5819 - val_accuracy: 0.8233 - val_loss: 0.5347
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 94ms/step - accuracy: 0.7968 - loss: 0.5892 - val_accuracy: 0.8207 - val_loss: 0.5669
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.8036 - loss: 0.5741 - val_accuracy: 0.8152 - val_loss: 0.5980
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 94ms/step - accuracy: 0.8037 - loss: 0.5739 - val_accuracy: 0.8044 - val_loss: 0.6207
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 79s 100ms/step - accuracy: 0.8062 - loss: 0.5599 - val_accuracy: 0.8521 - val_loss: 0.4460
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 100ms/step - accuracy: 0.8061 - loss: 0.5635 - val_accuracy: 0.8377 - val_loss: 0.5012
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.8005 - loss: 0.5667 - val_accuracy: 0.8475 - val_loss: 0.4608
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.8077 - loss: 0.5574 - val_accuracy: 0.8337 - val_loss: 0.5188
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 96ms/step - accuracy: 0.8130 - loss: 0.5514 - val_accuracy: 0.8364 - val_loss: 0.4873
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.8071 - loss: 0.5596 - val_accuracy: 0.8336 - val_loss: 0.5069
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.8076 - loss: 0.5561 - val_accuracy: 0.8371 - val_loss: 0.5157
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.8134 - loss: 0.5447 - val_accuracy: 0.8541 - val_loss: 0.4560
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 131s 167ms/step - accuracy: 0.8099 - loss: 0.5449 - val_accuracy: 0.8350 - val_loss: 0.5175
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.8089 - loss: 0.5521 - val_accuracy: 0.8526 - val_loss: 0.4597
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.8100 - loss: 0.5502 - val_accuracy: 0.8392 - val_loss: 0.5115
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 90
#      88 with open('model.json', 'w') as json_file:
#      89     json_file.write(model_json)
# ---> 90 model.save_weights('model.weight.h5')
#      92 #test
#      93 scores = model.evaluate(x_test, y_test, batch_size=128, verbose=1)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:217, in save_weights(model, filepath, overwrite, **kwargs)
#     214 @keras_export("keras.saving.save_weights")
#     215 def save_weights(model, filepath, overwrite=True, **kwargs):
#     216     if not str(filepath).endswith(".weights.h5"):
# --> 217         raise ValueError(
#     218             "The filename must end in `.weights.h5`. "
#     219             f"Received: filepath={filepath}"
#     220         )
#     221     try:
#     222         exists = os.path.exists(filepath)
#
# ValueError: The filename must end in `.weights.h5`. Received: filepath=model.weight.h5
